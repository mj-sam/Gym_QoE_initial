# %%
import pandas as pd

# %%
fields = ['episode', 'reward', 'ep_block_prob', 'ep_accepted_requests', 'avg_deployment_cost',
                  'avg_total_latency', 'avg_access_latency', 'avg_proc_latency',
                  'avg_throuput_in', 'avg_packetsize_in', 'avg_interarrival_in', 'avg_throuput_out','avg_packetsize_out','avg_interarrival_out','avg_qoe','gini',
                  'execution_time']

# %%
df = pd.read_csv('./nne_gym_results.csv', on_bad_lines='skip')

# %%
df
# Out:
#      episode  reward  ep_block_prob  ep_accepted_requests  \
# 0          1  -65.27           0.77                    23
# 1          2  -72.20           0.81                    19
# 2          3  -49.87           0.73                    27
# 3          4  -61.13           0.78                    22
# 4          5  -54.27           0.70                    30
# ..       ...     ...            ...                   ...
# 404      405   51.73           0.00                   100
# 405      406   78.33           0.01                    99
# 406      407   71.00           0.01                    99
# 407      408   53.73           0.00                   100
# 408      409   59.13           0.00                   100
#
#      avg_deployment_cost  avg_total_latency  avg_access_latency  \
# 0                   8.35              14.00                6.96
# 1                   9.05              25.68                7.37
# 2                   3.15              34.33                3.44
# 3                   4.50              48.25                4.25
# 4                   8.13              60.52                6.92
# ..                   ...                ...                 ...
# 404                 8.24           17022.35                7.15
# 405                 3.98           16982.27                4.39
# 406                 5.09           16873.04                3.79
# 407                 7.94           17578.37                5.33
# 408                 7.13           16896.12                5.46
#
#      avg_proc_latency  avg_throuput_in  avg_packetsize_in  \
# 0                7.04           368.32             307.66
# 1               18.32           313.20             263.59
# 2               30.89           126.12             147.69
# 3               44.00           405.33             326.34
# 4               53.60           405.57             326.12
# ..                ...              ...                ...
# 404          17015.20           278.29             245.12
# 405          16977.88           276.26             246.12
# 406          16869.25           254.28             231.98
# 407          17573.04           289.13             254.98
# 408          16890.66           146.76             160.24
#
#      avg_interarrival_in  avg_throuput_out  avg_packetsize_out  \
# 0                   0.18            382.36              316.59
# 1                   0.36            328.21              274.14
# 2                   0.56            140.33              166.00
# 3                   0.19            432.04              339.91
# 4                   0.19            416.23              329.18
# ..                   ...               ...                 ...
# 404                 0.35            303.43              265.61
# 405                 0.32            303.50              268.35
# 406                 0.35            285.27              258.21
# 407                 0.31            318.05              277.08
# 408                 0.52            180.77              191.18
#
#      avg_interarrival_out  avg_latency_binary  avg_jerkiness_binary  \
# 0                    0.17                0.74                  0.65
# 1                    0.33                0.58                  0.47
# 2                    0.51                0.74                  0.81
# 3                    0.18                0.68                  0.50
# 4                    0.17                0.77                  0.53
# ..                    ...                 ...                   ...
# 404                  0.32                0.73                  0.71
# 405                  0.30                0.69                  0.72
# 406                  0.32                0.73                  0.71
# 407                  0.28                0.69                  0.63
# 408                  0.48                0.77                  0.82
#
#      avg_sync_binary  avg_qoe  gini  execution_time
# 0               0.04     2.42  0.75            0.10
# 1               0.21     2.35  0.75            0.10
# 2               0.07     2.65  0.75            0.15
# 3               0.09     2.23  0.75            0.11
# 4               0.13     2.44  0.75            0.10
# ..               ...      ...   ...             ...
# 404             0.06     2.47  0.75            0.19
# 405             0.09     2.48  0.75            0.22
# 406             0.10     2.47  0.75            0.18
# 407             0.11     2.44  0.75            0.21
# 408             0.02     2.59  0.75            0.18
#
# [409 rows x 20 columns]

# %%
import matplotlib.pyplot as plt

# %%
# Plot the 'reward' column
plt.plot(df['avg_deployment_cost'])

# %%
# Plot the 'reward' column
plt.plot(df['avg_qoe'])

# %%
variables = [
    "r", "l", "t", "reward_step", "action", "reward", "ep_block_prob", "ep_accepted_requests",
    "avg_deployment_cost", "avg_total_latency", "avg_access_latency", "avg_processing_latency",
    "avg_throuput_in", "avg_packetsize_in", "avg_interarrival_in", "avg_throuput_out",
    "avg_packetsize_out", "avg_interarrival_out", "avg_latency_binary", "avg_jerkiness_binary",
    "avg_sync_binary", "gini", "executionTime"
]
len(variables)
# Out:
# 23

# %%
df
# Out:
#          1   0.66  0.14   86.0   7.81      22.72  6.89      15.74  0.09  \
# 0        2   9.68  0.06   94.0   6.38      23.61  6.17      17.36  0.08
# 1        3  -9.46  0.18   82.0   4.00      19.91  4.27      15.56  0.08
# 2        4  -6.55  0.16   84.0   4.42      26.60  4.17      22.36  0.07
# 3        5  -5.90  0.21   79.0   9.16      24.38  7.31      16.99  0.08
# 4        6  -1.36  0.15   85.0   1.98      24.69  2.34      22.28  0.07
# ...    ...    ...   ...    ...    ...        ...   ...        ...   ...
# 9462  2003   0.89  0.00  100.0   1.67  121478.82  1.60  121477.22   NaN
# 9463  2004   5.87  0.00  100.0   5.40  122811.79  4.53  122807.26   NaN
# 9464  2005   8.15  0.00  100.0   7.11  120443.01  6.21  120436.80   NaN
# 9465  2006   0.00  0.00  100.0   1.00  121803.38  1.00  121802.38   NaN
# 9466  2007  13.85  0.00  100.0  11.39  121224.41  7.71  121216.70   NaN
#
#       74.98  29.66  2.39  0.06  32.0  24.0  30.0  0.28
# 0     73.46  28.97  3.02  0.15  41.0  33.0  20.0  0.29
# 1     41.51  22.84  4.87  0.46  26.0  56.0   0.0  0.36
# 2     43.07  26.30  1.94  0.53  67.0   0.0  17.0  0.36
# 3     81.06  36.18  1.86  0.15  33.0  15.0  31.0  0.35
# 4     66.73  31.80  2.78  0.18  20.0  43.0  22.0  0.34
# ...     ...    ...   ...   ...   ...   ...   ...   ...
# 9462    NaN    NaN   NaN  0.75   NaN   NaN   NaN  0.12
# 9463    NaN    NaN   NaN  0.75   NaN   NaN   NaN  0.12
# 9464    NaN    NaN   NaN  0.75   NaN   NaN   NaN  0.12
# 9465    NaN    NaN   NaN  0.75   NaN   NaN   NaN  0.11
# 9466    NaN    NaN   NaN  0.75   NaN   NaN   NaN  0.12
#
# [9467 rows x 17 columns]
